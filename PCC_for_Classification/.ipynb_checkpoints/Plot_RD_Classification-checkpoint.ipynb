# %%
import os
import re

import bjontegaard as bd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set_theme(
    # context="paper",
    style="whitegrid",
    font="Times New Roman",
    # font_scale=1,
)

EPSILON = 1e-8

DATASET = "ModelNet10"
x = "bits"
y = "acc_top1"

CODEC_TYPES = ["full", "lite", "micro", "input-compression"]

CODECS = [
    "theoretical-optimum",
    "um-pcc-cls-only-pointnet-mmsp2023_size=full_points=1024",
    "um-pcc-cls-only-pointnet-mmsp2023_size=full_points=512",
    "um-pcc-cls-only-pointnet-mmsp2023_size=full_points=256",
    "um-pcc-cls-only-pointnet-mmsp2023_size=full_points=128",
    "um-pcc-cls-only-pointnet-mmsp2023_size=full_points=64",
    "um-pcc-cls-only-pointnet-mmsp2023_size=full_points=32",
    "um-pcc-cls-only-pointnet-mmsp2023_size=full_points=16",
    "um-pcc-cls-only-pointnet-mmsp2023_size=full_points=8",
    "um-pcc-cls-only-pointnet-mmsp2023_size=lite_points=1024",
    "um-pcc-cls-only-pointnet-mmsp2023_size=lite_points=512",
    "um-pcc-cls-only-pointnet-mmsp2023_size=lite_points=256",
    "um-pcc-cls-only-pointnet-mmsp2023_size=lite_points=128",
    "um-pcc-cls-only-pointnet-mmsp2023_size=lite_points=64",
    "um-pcc-cls-only-pointnet-mmsp2023_size=lite_points=32",
    "um-pcc-cls-only-pointnet-mmsp2023_size=lite_points=16",
    "um-pcc-cls-only-pointnet-mmsp2023_size=lite_points=8",
    "um-pcc-cls-only-pointnet-mmsp2023_size=micro_points=1024",
    "um-pcc-cls-only-pointnet-mmsp2023_size=micro_points=512",
    "um-pcc-cls-only-pointnet-mmsp2023_size=micro_points=256",
    "um-pcc-cls-only-pointnet-mmsp2023_size=micro_points=128",
    "um-pcc-cls-only-pointnet-mmsp2023_size=micro_points=64",
    "um-pcc-cls-only-pointnet-mmsp2023_size=micro_points=32",
    "um-pcc-cls-only-pointnet-mmsp2023_size=micro_points=16",
    "um-pcc-cls-only-pointnet-mmsp2023_size=micro_points=8",
    "input-compression-pointnet-tmc13",
    "input-compression-pointnet-octattention",
    "input-compression-pointnet-ipdae",
    "input-compression-pointnet-draco",
]

REF_CODEC_NAME = "Input compression codec [tmc13, P=*]"

COLORS = {
    "baseline_with_transform": "#CCCCCC",
    "baseline_no_transform": "#999999",
}

POINTNET_RESULTS = {
    '64': 0.927632 * 100,
    '128': 0.91557 * 100,
    '256': 0.926535 * 100
}
POINTNETPP_RESULTS = {
    '64': 0.934211 * 100,
    '128': 0.932018 * 100,
    '256': 0.930921 * 100
}

def plot_baseline(ax, resolution):
    _, x_max = ax.get_xlim()
    ax.plot(
        [0, x_max],
        [POINTNETPP_RESULTS[str(resolution)], POINTNETPP_RESULTS[str(resolution)]],
        label=f"PointNet++ [official] [{POINTNETPP_RESULTS[str(resolution)]:.{2}f}%]",
        color=COLORS["baseline_no_transform"],
        linestyle="--",
    )
    ax.plot(
        [0, x_max],
        [POINTNET_RESULTS[str(resolution)], POINTNET_RESULTS[str(resolution)]],
        label=f"PointNet [official] [{POINTNET_RESULTS[str(resolution)]:.{2}f}%]",
        color=COLORS["baseline_with_transform"],
        linestyle="--",
    )
    

def read_dataframe():
    df = pd.concat(
        [
            compressai_results_dataframe(
                filename=name,
                base_path="./",
            )
            for name in CODECS
        ]
    )

    def name_to_codec_type(name):
        name_pattern = r"^Proposed codec \[(?P<codec_type>[\w-]+), P=(?P<points>\d+)\]$"
        m = re.match(name_pattern, name)
        if m:
            return m.group("codec_type")
        return "input-compression"

    df["codec_type"] = df["name"].apply(name_to_codec_type)

    return df

# %%
import sys
sys.path.append('/media/avitech7/QuocAnh_1TB/Point_Cloud/source_code/compression_frameworks/learned-point-cloud-compression-for-classification')

from compressai_trainer.utils.compressai.results import compressai_results_dataframe

CODECS = [
    "MMSP2023_methods_res128.json",
    "GPCC_PointNetPP_res128.json",
]

df = read_dataframe()
print(df.to_string())


fig, ax = plt.subplots(figsize=(0.9 * 6.4, 1.0 * 4.8))

ax.set(
    xlabel="Rate (bits)",
    ylabel="Top-1 Accuracy (%)",
    xlim=[0, 3000],
    ylim=[0, 100],
)
palette = sns.color_palette("husl", 9)

plot_baseline(ax, 128)

codec_type = "input-compression"

mask = (df["codec_type"] == codec_type) | (df["name"] == REF_CODEC_NAME)
mask |= (df["codec_type"] == "input-compression")
df_curr = df[mask]
df_curr["acc_top1"] = df_curr["acc_top1"] * 100

sns.lineplot(ax=ax, data=df_curr, x=x, y=y, hue="name", palette=palette)
ax.legend().set_title(None)

fig.savefig(
    f"output.jpg",
    bbox_inches="tight",
    # pad_inches=0,
)
plt.show()
# Out:
#         bits  acc_top1                                     name model.name                                      description         codec_type
# 0     5.7500  0.698238                   Ulhaq and Bajic (2023)       None  learned PCC for classification (resolution 128)  input-compression
# 1     9.8400  0.795154                   Ulhaq and Bajic (2023)       None  learned PCC for classification (resolution 128)  input-compression
# 2    13.4300  0.866740                   Ulhaq and Bajic (2023)       None  learned PCC for classification (resolution 128)  input-compression
# 3    19.0700  0.882159                   Ulhaq and Bajic (2023)       None  learned PCC for classification (resolution 128)  input-compression
# 4    26.9900  0.896476                   Ulhaq and Bajic (2023)       None  learned PCC for classification (resolution 128)  input-compression
# 5    38.5900  0.901982                   Ulhaq and Bajic (2023)       None  learned PCC for classification (resolution 128)  input-compression
# 6    54.5900  0.908590                   Ulhaq and Bajic (2023)       None  learned PCC for classification (resolution 128)  input-compression
# 7   177.1600  0.911894                   Ulhaq and Bajic (2023)       None  learned PCC for classification (resolution 128)  input-compression
# 0   364.0529  0.110132  Input compression codec [tmc13, P=1024]       None              G-PCC + PointNet++ (resolution 128)  input-compression
# 1   444.5374  0.329295  Input compression codec [tmc13, P=1024]       None              G-PCC + PointNet++ (resolution 128)  input-compression
# 2   660.5639  0.736784  Input compression codec [tmc13, P=1024]       None              G-PCC + PointNet++ (resolution 128)  input-compression
# 3  1487.4009  0.874449  Input compression codec [tmc13, P=1024]       None              G-PCC + PointNet++ (resolution 128)  input-compression
# 4  4586.0176  0.916300  Input compression codec [tmc13, P=1024]       None              G-PCC + PointNet++ (resolution 128)  input-compression
# 5  6587.1542  0.926211  Input compression codec [tmc13, P=1024]       None              G-PCC + PointNet++ (resolution 128)  input-compression
# 6  7817.6123  0.932819  Input compression codec [tmc13, P=1024]       None              G-PCC + PointNet++ (resolution 128)  input-compression
# /tmp/ipykernel_1794811/1929227530.py:34: UserWarning: The palette list has more values (9) than needed (2), which may not be intended.
#   sns.lineplot(ax=ax, data=df_curr, x=x, y=y, hue="name", palette=palette)

# %%
df_curr
# Out:
#      bits  acc_top1                    name model.name  \
# 0    5.75  0.698238  Ulhaq and Bajic (2023)       None
# 1    9.84  0.795154  Ulhaq and Bajic (2023)       None
# 2   13.43  0.866740  Ulhaq and Bajic (2023)       None
# 3   19.07  0.882159  Ulhaq and Bajic (2023)       None
# 4   26.99  0.896476  Ulhaq and Bajic (2023)       None
# 5   38.59  0.901982  Ulhaq and Bajic (2023)       None
# 6   54.59  0.908590  Ulhaq and Bajic (2023)       None
# 7  177.16  0.911894  Ulhaq and Bajic (2023)       None
#
#                                        description         codec_type
# 0  learned PCC for classification (resolution 128)  input-compression
# 1  learned PCC for classification (resolution 128)  input-compression
# 2  learned PCC for classification (resolution 128)  input-compression
# 3  learned PCC for classification (resolution 128)  input-compression
# 4  learned PCC for classification (resolution 128)  input-compression
# 5  learned PCC for classification (resolution 128)  input-compression
# 6  learned PCC for classification (resolution 128)  input-compression
# 7  learned PCC for classification (resolution 128)  input-compression

# %%
df
# Out:
#      bits  acc_top1                    name model.name  \
# 0    5.75  0.698238  Ulhaq and Bajic (2023)       None
# 1    9.84  0.795154  Ulhaq and Bajic (2023)       None
# 2   13.43  0.866740  Ulhaq and Bajic (2023)       None
# 3   19.07  0.882159  Ulhaq and Bajic (2023)       None
# 4   26.99  0.896476  Ulhaq and Bajic (2023)       None
# 5   38.59  0.901982  Ulhaq and Bajic (2023)       None
# 6   54.59  0.908590  Ulhaq and Bajic (2023)       None
# 7  177.16  0.911894  Ulhaq and Bajic (2023)       None
#
#                                        description         codec_type
# 0  learned PCC for classification (resolution 128)  input-compression
# 1  learned PCC for classification (resolution 128)  input-compression
# 2  learned PCC for classification (resolution 128)  input-compression
# 3  learned PCC for classification (resolution 128)  input-compression
# 4  learned PCC for classification (resolution 128)  input-compression
# 5  learned PCC for classification (resolution 128)  input-compression
# 6  learned PCC for classification (resolution 128)  input-compression
# 7  learned PCC for classification (resolution 128)  input-compression

# %%
df_curr["acc_top1"]
# Out:
# 0    0.698238
# 1    0.795154
# 2    0.866740
# 3    0.882159
# 4    0.896476
# 5    0.901982
# 6    0.908590
# 7    0.911894
# Name: acc_top1, dtype: float64
